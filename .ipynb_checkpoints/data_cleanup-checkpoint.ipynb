# %%
# Include this line to make plots interactive
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Import CSVs
top1000 = pd.read_csv('data_sets/Highest Holywood Grossing Movies.csv')
top5000 = pd.read_csv('data_sets/tmdb_5000_movies.csv')

top1000.head()
#top5000.head()
# Out:
#    Unnamed: 0                                              Title  \
# 0           0  Star Wars: Episode VII - The Force Awakens (2015)
# 1           1                           Avengers: Endgame (2019)
# 2           2                                      Avatar (2009)
# 3           3                               Black Panther (2018)
# 4           4                      Avengers: Infinity War (2018)
#
#                                           Movie Info  \
# 0  As a new threat to the galaxy rises, Rey, a de...
# 1  After the devastating events of Avengers: Infi...
# 2  A paraplegic Marine dispatched to the moon Pan...
# 3  T'Challa, heir to the hidden but advanced king...
# 4  The Avengers and their allies must be willing ...
#
#                            Distributor Release Date  Domestic Sales (in $)  \
# 0  Walt Disney Studios Motion Pictures    16-Dec-15              936662225
# 1  Walt Disney Studios Motion Pictures    24-Apr-19              858373000
# 2                Twentieth Century Fox    16-Dec-09              760507625
# 3  Walt Disney Studios Motion Pictures          NaN              700426566
# 4  Walt Disney Studios Motion Pictures          NaN              678815482
#
#    International Sales (in $)  World Sales (in $)  \
# 0                  1132859475          2069521700
# 1                  1939128328          2797501328
# 2                  2086738578          2847246203
# 3                   647171407          1347597973
# 4                  1369544272          2048359754
#
#                                 Genre Movie Runtime License
# 0           Action, Adventure, Sci-Fi   2 hr 18 min   PG-13
# 1    Action, Adventure, Drama, Sci-Fi    3 hr 1 min   PG-13
# 2  Action, Adventure, Fantasy, Sci-Fi   2 hr 42 min   PG-13
# 3           Action, Adventure, Sci-Fi   2 hr 14 min     NaN
# 4           Action, Adventure, Sci-Fi   2 hr 29 min     NaN

# %%
#Clean up data. Rows to keep: Top1000: 'Title', 'Distributor', 'Domestic Sales (in $)', 'International Sales (in $)', 'Genre'
#Top 5000:'title', 'vote_average', 'revenue', 'release_date', 'budget'

top1000 = top1000[['Title', 'Distributor', 'Domestic Sales (in $)', 'International Sales (in $)', 'Genre']]
top5000 = top5000[['title', 'vote_average', 'release_date', 'revenue', 'budget']]

top1000.head()
#top5000.head()
# Out:
#                                                Title  \
# 0  Star Wars: Episode VII - The Force Awakens (2015)
# 1                           Avengers: Endgame (2019)
# 2                                      Avatar (2009)
# 3                               Black Panther (2018)
# 4                      Avengers: Infinity War (2018)
#
#                            Distributor  Domestic Sales (in $)  \
# 0  Walt Disney Studios Motion Pictures              936662225
# 1  Walt Disney Studios Motion Pictures              858373000
# 2                Twentieth Century Fox              760507625
# 3  Walt Disney Studios Motion Pictures              700426566
# 4  Walt Disney Studios Motion Pictures              678815482
#
#    International Sales (in $)                               Genre
# 0                  1132859475           Action, Adventure, Sci-Fi
# 1                  1939128328    Action, Adventure, Drama, Sci-Fi
# 2                  2086738578  Action, Adventure, Fantasy, Sci-Fi
# 3                   647171407           Action, Adventure, Sci-Fi
# 4                  1369544272           Action, Adventure, Sci-Fi

# %%
#Clean up titles in Top1000 for easier merge

new_title = []

for x in top1000['Title']:
    
    old_title = x
    size = len(old_title)
    # Slice string to remove last 3 characters from
    Title = old_title[:size - 7]
    new_title.append(Title)
    #top1000.replace(to_replace= top1000['Title'], 
                     #value=Title 
                     #)
            
del top1000['Title']


            
top1000['title'] =  new_title


top1000.head()
# Out:
#                            Distributor  Domestic Sales (in $)  \
# 0  Walt Disney Studios Motion Pictures              936662225
# 1  Walt Disney Studios Motion Pictures              858373000
# 2                Twentieth Century Fox              760507625
# 3  Walt Disney Studios Motion Pictures              700426566
# 4  Walt Disney Studios Motion Pictures              678815482
#
#    International Sales (in $)                               Genre  \
# 0                  1132859475           Action, Adventure, Sci-Fi
# 1                  1939128328    Action, Adventure, Drama, Sci-Fi
# 2                  2086738578  Action, Adventure, Fantasy, Sci-Fi
# 3                   647171407           Action, Adventure, Sci-Fi
# 4                  1369544272           Action, Adventure, Sci-Fi
#
#                                         title
# 0  Star Wars: Episode VII - The Force Awakens
# 1                           Avengers: Endgame
# 2                                      Avatar
# 3                               Black Panther
# 4                      Avengers: Infinity War

# %%
#merge the two datasets

final_movie_dataset = top1000.merge(top5000, how='left', on='title')

final_movie_dataset = final_movie_dataset.dropna(how='any',axis=0) 

final_movie_dataset.head()

#final_movie_dataset['release_date'].max()
# Out:
#                             Distributor  Domestic Sales (in $)  \
# 2                 Twentieth Century Fox              760507625
# 6                    Paramount Pictures              659363944
# 7                    Universal Pictures              652385625
# 8   Walt Disney Studios Motion Pictures              623357910
# 11  Walt Disney Studios Motion Pictures              543638043
#
#     International Sales (in $)                                         Genre  \
# 2                   2086738578            Action, Adventure, Fantasy, Sci-Fi
# 6                   1542283320                                Drama, Romance
# 7                   1018130819                     Action, Adventure, Sci-Fi
# 8                    895457605                     Action, Adventure, Sci-Fi
# 11                  1119261396  Adventure, Animation, Drama, Family, Musical
#
#              title  vote_average release_date       revenue       budget
# 2           Avatar           7.2   2009-12-10  2.787965e+09  237000000.0
# 6          Titanic           7.5   1997-11-18  1.845034e+09  200000000.0
# 7   Jurassic World           6.5   2015-06-09  1.513529e+09  150000000.0
# 8     The Avengers           7.4   2012-04-25  1.519558e+09  220000000.0
# 11   The Lion King           8.0   1994-06-23  7.882418e+08   45000000.0

# %%
#Update revenue

for row in final_movie_dataset:
    new_rev = (final_movie_dataset['Domestic Sales (in $)']+ final_movie_dataset['International Sales (in $)'])

    
    
del final_movie_dataset['revenue']


            
final_movie_dataset['Revenue'] =  new_rev

final_movie_dataset.head()
# Out:
#                             Distributor  Domestic Sales (in $)  \
# 2                 Twentieth Century Fox              760507625
# 6                    Paramount Pictures              659363944
# 7                    Universal Pictures              652385625
# 8   Walt Disney Studios Motion Pictures              623357910
# 11  Walt Disney Studios Motion Pictures              543638043
#
#     International Sales (in $)                                         Genre  \
# 2                   2086738578            Action, Adventure, Fantasy, Sci-Fi
# 6                   1542283320                                Drama, Romance
# 7                   1018130819                     Action, Adventure, Sci-Fi
# 8                    895457605                     Action, Adventure, Sci-Fi
# 11                  1119261396  Adventure, Animation, Drama, Family, Musical
#
#              title  vote_average release_date       budget     Revenue
# 2           Avatar           7.2   2009-12-10  237000000.0  2847246203
# 6          Titanic           7.5   1997-11-18  200000000.0  2201647264
# 7   Jurassic World           6.5   2015-06-09  150000000.0  1670516444
# 8     The Avengers           7.4   2012-04-25  220000000.0  1518815515
# 11   The Lion King           8.0   1994-06-23   45000000.0  1662899439

# %%
#Create profit column

for row in final_movie_dataset:
    value = (final_movie_dataset['Revenue']- final_movie_dataset['budget'])
  


final_movie_dataset['Profit/Loss']= value

final_movie_dataset.head()
# Out:
#                             Distributor  Domestic Sales (in $)  \
# 2                 Twentieth Century Fox              760507625
# 6                    Paramount Pictures              659363944
# 7                    Universal Pictures              652385625
# 8   Walt Disney Studios Motion Pictures              623357910
# 11  Walt Disney Studios Motion Pictures              543638043
#
#     International Sales (in $)                                         Genre  \
# 2                   2086738578            Action, Adventure, Fantasy, Sci-Fi
# 6                   1542283320                                Drama, Romance
# 7                   1018130819                     Action, Adventure, Sci-Fi
# 8                    895457605                     Action, Adventure, Sci-Fi
# 11                  1119261396  Adventure, Animation, Drama, Family, Musical
#
#              title  vote_average release_date       budget     Revenue  \
# 2           Avatar           7.2   2009-12-10  237000000.0  2847246203
# 6          Titanic           7.5   1997-11-18  200000000.0  2201647264
# 7   Jurassic World           6.5   2015-06-09  150000000.0  1670516444
# 8     The Avengers           7.4   2012-04-25  220000000.0  1518815515
# 11   The Lion King           8.0   1994-06-23   45000000.0  1662899439
#
#      Profit/Loss
# 2   2.610246e+09
# 6   2.001647e+09
# 7   1.520516e+09
# 8   1.298816e+09
# 11  1.617899e+09

# %%
#Calculate domestic and international sales distributions


for row in final_movie_dataset:
    dom_rate = ((final_movie_dataset['Domestic Sales (in $)']/final_movie_dataset['Revenue'])*100).map("{:.2f}%".format)
    
final_movie_dataset['Domestic Sales (as % of total Revenue)'] = dom_rate

for row in final_movie_dataset:
    int_rate = ((final_movie_dataset['International Sales (in $)']/final_movie_dataset['Revenue'])*100).map("{:.2f}%".format)
    
final_movie_dataset['International Sales (as % of total Revenue)'] = int_rate

#Organize columns into more logical order

final_movie_dataset = final_movie_dataset[['title',
                                           'Distributor',
                                           'Genre',
                                           'release_date',
                                           'budget',
                                           'Domestic Sales (in $)',
                                           'International Sales (in $)',
                                           'Domestic Sales (as % of total Revenue)',
                                           'International Sales (as % of total Revenue)',
                                           'Revenue',
                                           'Profit/Loss',
                                           'vote_average'
                                          ]]


final_movie_dataset.head()
# Out:
#              title                          Distributor  \
# 2           Avatar                Twentieth Century Fox
# 6          Titanic                   Paramount Pictures
# 7   Jurassic World                   Universal Pictures
# 8     The Avengers  Walt Disney Studios Motion Pictures
# 11   The Lion King  Walt Disney Studios Motion Pictures
#
#                                            Genre release_date       budget  \
# 2             Action, Adventure, Fantasy, Sci-Fi   2009-12-10  237000000.0
# 6                                 Drama, Romance   1997-11-18  200000000.0
# 7                      Action, Adventure, Sci-Fi   2015-06-09  150000000.0
# 8                      Action, Adventure, Sci-Fi   2012-04-25  220000000.0
# 11  Adventure, Animation, Drama, Family, Musical   1994-06-23   45000000.0
#
#     Domestic Sales (in $)  International Sales (in $)  \
# 2               760507625                  2086738578
# 6               659363944                  1542283320
# 7               652385625                  1018130819
# 8               623357910                   895457605
# 11              543638043                  1119261396
#
#    Domestic Sales (as % of total Revenue)  \
# 2                                  26.71%
# 6                                  29.95%
# 7                                  39.05%
# 8                                  41.04%
# 11                                 32.69%
#
#    International Sales (as % of total Revenue)     Revenue   Profit/Loss  \
# 2                                       73.29%  2847246203  2.610246e+09
# 6                                       70.05%  2201647264  2.001647e+09
# 7                                       60.95%  1670516444  1.520516e+09
# 8                                       58.96%  1518815515  1.298816e+09
# 11                                      67.31%  1662899439  1.617899e+09
#
#     vote_average
# 2            7.2
# 6            7.5
# 7            6.5
# 8            7.4
# 11           8.0

# %%
list1 = final_movie_dataset['Genre'].tolist()

unique_list = []


for entry in list1:
    #Split the string into a list
    genres_from_entry = entry.split(", ")

    #For loop to add genre to unique_list if not alredy in unique_list
    for genre in genres_from_entry:
        if genre not in unique_list:
            unique_list.append(genre)

# %%
#output of unique_list
unique_list
# Out:
# ['Action',
#  'Adventure',
#  'Fantasy',
#  'Sci-Fi',
#  'Drama',
#  'Romance',
#  'Animation',
#  'Family',
#  'Musical',
#  'Crime',
#  'Thriller',
#  'Comedy',
#  'Biography',
#  'War',
#  'Mystery',
#  'Sport',
#  'Horror',
#  'Music',
#  'History',
#  'Western',
#  'Documentary']

# %%
# Create empty dictionary to hold genre info
genre_dict = {}

# %%
###Add each unique genre to the dictionary with###

#Loop through unique_list
for entry in unique_list:

    ##Create dictionary entry to genre
    genre_dict.update(
        {
            #Make key for each genre based on genre name + '_dict_key'
            entry.lower() + '_dict_key': 
            {
                #Create Key-Value pairs
                "genre" : entry,
                "genre_total_title_count" : 0,
                "genre_total_budget" : 0,
                "genre_total_revenue" : 0,
                "genre_domestic_sales" : 0,
                "genre_international_sales" : 0,
                "sum_vote_average" : 0,
                "movie_title_list" : []
            
            
            
            
            
            }
        }



    )

# %%
# for loop to index through each row of the dataframe
for index, row in final_movie_dataset.iterrows():
    #row by row within for loop, creates a list of lowercase genres for each 
    genre_list_by_movie = row['Genre'].lower().split(", ")
    
    # For Loop to go through each element of the genre_list_by_movie
    for genre in genre_list_by_movie:

        #sets variable that will be used to access correct dictionary item by key
        genre_dict_key = genre + '_dict_key'
        
        #Set the dictionary values for the corresponding elements
        genre_dict[genre_dict_key]['genre_total_title_count'] = genre_dict[genre_dict_key]['genre_total_title_count'] + 1
        genre_dict[genre_dict_key]['genre_total_budget'] = genre_dict[genre_dict_key]['genre_total_budget'] + row['budget']
        genre_dict[genre_dict_key]['genre_total_revenue'] = genre_dict[genre_dict_key]['genre_total_revenue'] + row['Revenue']
        genre_dict[genre_dict_key]['genre_domestic_sales'] = genre_dict[genre_dict_key]['genre_domestic_sales'] + row['Domestic Sales (in $)']
        genre_dict[genre_dict_key]['genre_international_sales'] = genre_dict[genre_dict_key]['genre_international_sales'] + row['International Sales (in $)']
        genre_dict[genre_dict_key]['sum_vote_average'] = genre_dict[genre_dict_key]['sum_vote_average'] + row['vote_average']
        genre_dict[genre_dict_key]['movie_title_list'].append(row['title'])

# %%
#Make new dataframe from genre_dict
genre_df = pd.DataFrame.from_dict(genre_dict,orient='index')


#reset so index is numeric
genre_df.reset_index(drop=True,inplace=True)

# %%
#Output of genre_df
genre_df.head()
# Out:
#        genre  genre_total_title_count  genre_total_budget  \
# 0     Action                      300        3.377368e+10
# 1  Adventure                      316        3.700137e+10
# 2    Fantasy                      154        1.744549e+10
# 3     Sci-Fi                      160        1.966200e+10
# 4      Drama                      230        1.542450e+10
#
#    genre_total_revenue  genre_domestic_sales  genre_international_sales  \
# 0         131813301506           53560793805                78252507701
# 1         159520075328           61956135804                97563939524
# 2          73400721969           28947837246                44452884723
# 3          78830235034           31693650614                47136584420
# 4          76009228534           34665514684                41343713850
#
#    sum_vote_average                                   movie_title_list
# 0            1938.7  [Avatar, Jurassic World, The Avengers, The Dar...
# 1            2050.9  [Avatar, Jurassic World, The Avengers, The Lio...
# 2             982.7  [Avatar, Star Wars: Episode I - The Phantom Me...
# 3            1037.7  [Avatar, Jurassic World, The Avengers, Star Wa...
# 4            1581.4  [Titanic, The Lion King, The Dark Knight, The ...

# %%
#import numpy
import numpy as np

#Barchart for profit/loss by genre
genre_df['genre_total_profit/loss (in millions)'] = round((genre_df['genre_total_revenue']-genre_df['genre_total_budget'])/1000000, 2)

genre_df.head()

#sort by Profit/Loss
sorted_df = genre_df.sort_values(by=['genre_total_profit/loss (in millions)'], ascending=False)

genre = sorted_df['genre']
x_axis = sorted_df['genre']
PnL = sorted_df['genre_total_profit/loss (in millions)']

plt.figure(figsize=(10,11))
plt.bar(x_axis, PnL, color='green')
plt.ylabel('Profit/Loss ($)')
plt.xlabel('Genre')
plt.title('Profit & Loss by Genre')
plt.xticks(rotation = '65')
plt.savefig("Profit & Loss by Genre.png")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
